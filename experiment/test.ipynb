# %%
import pandas as pd

# %%
sam = {
  "code": 200,
  "message": "상권 추정 매출 데이터 조회에 성공했습니다.",
  "data": [
    {
      "상권_코드_명": "가락시장역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "가락본동",
      "경도": 127.11872437303792,
      "위도": 37.494695372813744,
      "매출액": {
        "여성_매출_금액": 139997917,
        "남성_매출_금액": 129382799,
        "연령대_10_매출_금액": 3631550,
        "연령대_20_매출_금액": 21066475,
        "연령대_30_매출_금액": 64872232,
        "연령대_40_매출_금액": 74809628,
        "연령대_50_매출_금액": 79171234,
        "연령대_60_이상_매출_금액": 25829597
      },
      "id": "1042",
      "distance": 0.18209337150103438
    },
    {
      "상권_코드_명": "경찰병원역 4번(건너말공원)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "가락본동",
      "경도": 127.12347042338958,
      "위도": 37.49264522302983,
      "매출액": {
        "여성_매출_금액": 245526,
        "남성_매출_금액": 157838,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 0,
        "연령대_30_매출_금액": 78919,
        "연령대_40_매출_금액": 0,
        "연령대_50_매출_금액": 324445,
        "연령대_60_이상_매출_금액": 0
      },
      "id": "0e73",
      "distance": 0.46221435263002925
    },
    {
      "상권_코드_명": "경찰병원역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "가락본동",
      "경도": 127.12080906154488,
      "위도": 37.497171026507736,
      "매출액": {
        "여성_매출_금액": 129497110,
        "남성_매출_금액": 160522865,
        "연령대_10_매출_금액": 501550,
        "연령대_20_매출_금액": 38743470,
        "연령대_30_매출_금액": 64732084,
        "연령대_40_매출_금액": 93981703,
        "연령대_50_매출_금액": 58655062,
        "연령대_60_이상_매출_금액": 33406107
      },
      "id": "0668",
      "distance": 0.5054270841769698
    },
    {
      "상권_코드_명": "문정동 로데오거리 상점가(문정동 로데오거리)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "가락본동",
      "경도": 127.12321722571214,
      "위도": 37.48995147671527,
      "매출액": {
        "여성_매출_금액": 85869346,
        "남성_매출_금액": 59453020,
        "연령대_10_매출_금액": 781609,
        "연령대_20_매출_금액": 16338226,
        "연령대_30_매출_금액": 32592108,
        "연령대_40_매출_금액": 33702666,
        "연령대_50_매출_금액": 44658866,
        "연령대_60_이상_매출_금액": 17248891
      },
      "id": "2d65",
      "distance": 0.5599858206392418
    },
    {
      "상권_코드_명": "경찰병원역 3번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "가락2동",
      "경도": 127.12587022274428,
      "위도": 37.494156381623775,
      "매출액": {
        "여성_매출_금액": 37005173,
        "남성_매출_금액": 33857002,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 9653015,
        "연령대_30_매출_금액": 7599387,
        "연령대_40_매출_금액": 17160183,
        "연령대_50_매출_금액": 20644561,
        "연령대_60_이상_매출_금액": 15805029
      },
      "id": "bf77",
      "distance": 0.6813809452237432
    },
    {
      "상권_코드_명": "문정역 1번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "문정1동",
      "경도": 127.1231233502374,
      "위도": 37.48787024777591,
      "매출액": {
        "여성_매출_금액": 13145974,
        "남성_매출_금액": 12928675,
        "연령대_10_매출_금액": 129602,
        "연령대_20_매출_금액": 2194595,
        "연령대_30_매출_금액": 5878321,
        "연령대_40_매출_금액": 8653101,
        "연령대_50_매출_금액": 6389384,
        "연령대_60_이상_매출_금액": 2829646
      },
      "id": "ff73",
      "distance": 0.7224794018710201
    },
    {
      "상권_코드_명": "문정초등학교",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "문정1동",
      "경도": 127.12648283683586,
      "위도": 37.48862354516316,
      "매출액": {
        "여성_매출_금액": 19831360,
        "남성_매출_금액": 15326930,
        "연령대_10_매출_금액": 653570,
        "연령대_20_매출_금액": 1466994,
        "연령대_30_매출_금액": 3786997,
        "연령대_40_매출_금액": 8358496,
        "연령대_50_매출_금액": 8910128,
        "연령대_60_이상_매출_금액": 11982105
      },
      "id": "9bec",
      "distance": 0.8795758117926052
    },
    {
      "상권_코드_명": "송파역 2번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "송파2동",
      "경도": 127.11534113261456,
      "위도": 37.500681404240055,
      "매출액": {
        "여성_매출_금액": 11916644,
        "남성_매출_금액": 3664887,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 536397,
        "연령대_30_매출_금액": 84520,
        "연령대_40_매출_금액": 5221124,
        "연령대_50_매출_금액": 6118178,
        "연령대_60_이상_매출_금액": 3621312
      },
      "id": "1196",
      "distance": 0.8816152220977609
    },
    {
      "상권_코드_명": "송파사거리(송파역)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "석촌동",
      "경도": 127.11030924458171,
      "위도": 37.50111869275051,
      "매출액": {
        "여성_매출_금액": 96727374,
        "남성_매출_금액": 72031373,
        "연령대_10_매출_금액": 3388380,
        "연령대_20_매출_금액": 23737088,
        "연령대_30_매출_금액": 34697307,
        "연령대_40_매출_금액": 43911459,
        "연령대_50_매출_금액": 43194227,
        "연령대_60_이상_매출_금액": 19830286
      },
      "id": "a573",
      "distance": 1.1346776473522353
    },
    {
      "상권_코드_명": "오금역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "가락본동",
      "경도": 127.12614312912416,
      "위도": 37.50177860016498,
      "매출액": {
        "여성_매출_금액": 50799805,
        "남성_매출_금액": 60809155,
        "연령대_10_매출_금액": 279134,
        "연령대_20_매출_금액": 6424201,
        "연령대_30_매출_금액": 12627356,
        "연령대_40_매출_금액": 22964480,
        "연령대_50_매출_금액": 51555024,
        "연령대_60_이상_매출_금액": 17758765
      },
      "id": "8efd",
      "distance": 1.1894238992928021
    },
    {
      "상권_코드_명": "문정역 2번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "문정1동",
      "경도": 127.12601152245664,
      "위도": 37.48402890980623,
      "매출액": {
        "여성_매출_금액": 39884514,
        "남성_매출_금액": 37747528,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 2414647,
        "연령대_30_매출_금액": 12866631,
        "연령대_40_매출_금액": 24477181,
        "연령대_50_매출_금액": 30492122,
        "연령대_60_이상_매출_금액": 7381461
      },
      "id": "f8e0",
      "distance": 1.2184583011457215
    },
    {
      "상권_코드_명": "석촌중학교(방이육교)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "가락본동",
      "경도": 127.12460694915104,
      "위도": 37.502906487064415,
      "매출액": {
        "여성_매출_금액": 4951777,
        "남성_매출_금액": 4917230,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 191299,
        "연령대_30_매출_금액": 1034048,
        "연령대_40_매출_금액": 1714541,
        "연령대_50_매출_금액": 2691168,
        "연령대_60_이상_매출_금액": 4237951
      },
      "id": "6794",
      "distance": 1.2257507895832516
    },
    {
      "상권_코드_명": "석촌시장",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "석촌동",
      "경도": 127.10705115305088,
      "위도": 37.50037385552647,
      "매출액": {
        "여성_매출_금액": 417431640,
        "남성_매출_금액": 302683857,
        "연령대_10_매출_금액": 2378853,
        "연령대_20_매출_금액": 85159107,
        "연령대_30_매출_금액": 230260529,
        "연령대_40_매출_금액": 206503120,
        "연령대_50_매출_금액": 151948356,
        "연령대_60_이상_매출_금액": 43865531
      },
      "id": "c6b6",
      "distance": 1.2777425318343414
    },
    {
      "상권_코드_명": "장지동주민센터(한림연예예술고교)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "장지동",
      "경도": 127.1305941940208,
      "위도": 37.486051200890266,
      "매출액": {
        "여성_매출_금액": 28608409,
        "남성_매출_금액": 24820752,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 1532755,
        "연령대_30_매출_금액": 7470085,
        "연령대_40_매출_금액": 13080879,
        "연령대_50_매출_금액": 15635557,
        "연령대_60_이상_매출_금액": 15709886
      },
      "id": "2710",
      "distance": 1.3408682535450256
    },
    {
      "상권_코드_명": "문정동성당",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "장지동",
      "경도": 127.13328829277718,
      "위도": 37.487778126640926,
      "매출액": {
        "여성_매출_금액": 34189121,
        "남성_매출_금액": 29119001,
        "연령대_10_매출_금액": 447174,
        "연령대_20_매출_금액": 3266033,
        "연령대_30_매출_금액": 9110603,
        "연령대_40_매출_금액": 33751307,
        "연령대_50_매출_금액": 12894833,
        "연령대_60_이상_매출_금액": 3838172
      },
      "id": "eb07",
      "distance": 1.4517251133975981
    },
    {
      "상권_코드_명": "수서역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강남구",
      "행정동_코드_명": "수서동",
      "경도": 127.1030304624676,
      "위도": 37.487781357677065,
      "매출액": {
        "여성_매출_금액": 294887097,
        "남성_매출_금액": 286350523,
        "연령대_10_매출_금액": 2088225,
        "연령대_20_매출_금액": 45702363,
        "연령대_30_매출_금액": 122382133,
        "연령대_40_매출_금액": 145535577,
        "연령대_50_매출_금액": 160195524,
        "연령대_60_이상_매출_금액": 105333798
      },
      "id": "528f",
      "distance": 1.4682553190032643
    },
    {
      "상권_코드_명": "개롱역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "가락2동",
      "경도": 127.13460345002984,
      "위도": 37.49604787721762,
      "매출액": {
        "여성_매출_금액": 260158308,
        "남성_매출_금액": 203645914,
        "연령대_10_매출_금액": 6120661,
        "연령대_20_매출_금액": 49481944,
        "연령대_30_매출_금액": 106215738,
        "연령대_40_매출_금액": 139018662,
        "연령대_50_매출_금액": 120817500,
        "연령대_60_이상_매출_금액": 42149717
      },
      "id": "4980",
      "distance": 1.4784447001340242
    },
    {
      "상권_코드_명": "문현중학교(장지역 1번)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "장지동",
      "경도": 127.12733063992444,
      "위도": 37.48182002557716,
      "매출액": {
        "여성_매출_금액": 17359789,
        "남성_매출_금액": 7748852,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 436931,
        "연령대_30_매출_금액": 3116467,
        "연령대_40_매출_금액": 4358386,
        "연령대_50_매출_금액": 5125778,
        "연령대_60_이상_매출_금액": 12071079
      },
      "id": "3db7",
      "distance": 1.487656032324072
    },
    {
      "상권_코드_명": "석촌역 6번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "석촌동",
      "경도": 127.10561747375874,
      "위도": 37.50219517719213,
      "매출액": {
        "여성_매출_금액": 72616579,
        "남성_매출_금액": 56542541,
        "연령대_10_매출_금액": 1360726,
        "연령대_20_매출_금액": 5970701,
        "연령대_30_매출_금액": 26617020,
        "연령대_40_매출_금액": 24747117,
        "연령대_50_매출_금액": 26540337,
        "연령대_60_이상_매출_금액": 43923219
      },
      "id": "6cc3",
      "distance": 1.5058051021426502
    },
    {
      "상권_코드_명": "석촌역 3번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "송파1동",
      "경도": 127.11191117169508,
      "위도": 37.50603667404323,
      "매출액": {
        "여성_매출_금액": 194517132,
        "남성_매출_금액": 112768647,
        "연령대_10_매출_금액": 519460,
        "연령대_20_매출_금액": 43751537,
        "연령대_30_매출_금액": 76388636,
        "연령대_40_매출_금액": 67299355,
        "연령대_50_매출_금액": 66466852,
        "연령대_60_이상_매출_금액": 52859937
      },
      "id": "463e",
      "distance": 1.543845039353792
    },
    {
      "상권_코드_명": "방이동고분군(방산고등학교)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "방이1동",
      "경도": 127.1206099818534,
      "위도": 37.50698317749334,
      "매출액": {
        "여성_매출_금액": 16583111,
        "남성_매출_금액": 22434163,
        "연령대_10_매출_금액": 858212,
        "연령대_20_매출_금액": 872400,
        "연령대_30_매출_금액": 2360280,
        "연령대_40_매출_금액": 12245018,
        "연령대_50_매출_금액": 13044756,
        "연령대_60_이상_매출_금액": 9636608
      },
      "id": "27db",
      "distance": 1.5576465437387377
    },
    {
      "상권_코드_명": "투구봉어린이공원",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "가락2동",
      "경도": 127.13703070858396,
      "위도": 37.4938376214479,
      "매출액": {
        "여성_매출_금액": 2249113,
        "남성_매출_금액": 1419343,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 327540,
        "연령대_30_매출_금액": 436721,
        "연령대_40_매출_금액": 1255574,
        "연령대_50_매출_금액": 928031,
        "연령대_60_이상_매출_금액": 720590
      },
      "id": "7e9a",
      "distance": 1.6578300299454825
    },
    {
      "상권_코드_명": "장지역(가든파이브)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "문정2동",
      "경도": 127.1232994165398,
      "위도": 37.47804006486016,
      "매출액": {
        "여성_매출_금액": 135497147,
        "남성_매출_금액": 149792491,
        "연령대_10_매출_금액": 440139,
        "연령대_20_매출_금액": 29244122,
        "연령대_30_매출_금액": 73718203,
        "연령대_40_매출_금액": 88770688,
        "연령대_50_매출_금액": 68593175,
        "연령대_60_이상_매출_금액": 24523311
      },
      "id": "0dd6",
      "distance": 1.732473311492474
    },
    {
      "상권_코드_명": "석촌고분역 3번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "석촌동",
      "경도": 127.1003217674192,
      "위도": 37.49998331948502,
      "매출액": {
        "여성_매출_금액": 102975855,
        "남성_매출_금액": 73415338,
        "연령대_10_매출_금액": 248076,
        "연령대_20_매출_금액": 21825892,
        "연령대_30_매출_금액": 24433594,
        "연령대_40_매출_금액": 60460590,
        "연령대_50_매출_금액": 46747952,
        "연령대_60_이상_매출_금액": 22675089
      },
      "id": "80f1",
      "distance": 1.7581555029230331
    },
    {
      "상권_코드_명": "석촌역(석촌호수)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "송파1동",
      "경도": 127.1065389661683,
      "위도": 37.50602362134798,
      "매출액": {
        "여성_매출_금액": 292445943,
        "남성_매출_금액": 217359833,
        "연령대_10_매출_금액": 2054218,
        "연령대_20_매출_금액": 109113001,
        "연령대_30_매출_금액": 206899267,
        "연령대_40_매출_금액": 88102089,
        "연령대_50_매출_금액": 75359823,
        "연령대_60_이상_매출_금액": 28277380
      },
      "id": "aabc",
      "distance": 1.7705877179585412
    },
    {
      "상권_코드_명": "방이역 2번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "오금동",
      "경도": 127.12947590742026,
      "위도": 37.506334079138135,
      "매출액": {
        "여성_매출_금액": 100893418,
        "남성_매출_금액": 64046243,
        "연령대_10_매출_금액": 1379221,
        "연령대_20_매출_금액": 15682976,
        "연령대_30_매출_금액": 33969600,
        "연령대_40_매출_금액": 27024823,
        "연령대_50_매출_금액": 32867448,
        "연령대_60_이상_매출_금액": 54015593
      },
      "id": "5951",
      "distance": 1.773201946536339
    },
    {
      "상권_코드_명": "오금공원(오주중학교)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "오금동",
      "경도": 127.13464963793048,
      "위도": 37.502877446707714,
      "매출액": {
        "여성_매출_금액": 3008795,
        "남성_매출_금액": 1929628,
        "연령대_10_매출_금액": 39855,
        "연령대_20_매출_금액": 0,
        "연령대_30_매출_금액": 931159,
        "연령대_40_매출_금액": 1517415,
        "연령대_50_매출_금액": 919459,
        "연령대_60_이상_매출_금액": 1530534
      },
      "id": "5302",
      "distance": 1.8088844403279973
    },
    {
      "상권_코드_명": "방이역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "방이1동",
      "경도": 127.1253978901468,
      "위도": 37.509239712678266,
      "매출액": {
        "여성_매출_금액": 107956073,
        "남성_매출_금액": 71862715,
        "연령대_10_매출_금액": 1489427,
        "연령대_20_매출_금액": 37316152,
        "연령대_30_매출_금액": 33204799,
        "연령대_40_매출_금액": 41108861,
        "연령대_50_매출_금액": 49969216,
        "연령대_60_이상_매출_금액": 16730333
      },
      "id": "dde3",
      "distance": 1.901910749890477
    },
    {
      "상권_코드_명": "송파나루역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "송파1동",
      "경도": 127.11204169365998,
      "위도": 37.51012711047405,
      "매출액": {
        "여성_매출_금액": 47970440,
        "남성_매출_금액": 23737188,
        "연령대_10_매출_금액": 395597,
        "연령대_20_매출_금액": 15305644,
        "연령대_30_매출_금액": 27240413,
        "연령대_40_매출_금액": 8109573,
        "연령대_50_매출_금액": 13648884,
        "연령대_60_이상_매출_금액": 7007517
      },
      "id": "bb02",
      "distance": 1.9713389279258402
    },
    {
      "상권_코드_명": "보인중학교",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "오금동",
      "경도": 127.13906576695736,
      "위도": 37.49972782218089,
      "매출액": {
        "여성_매출_금액": 16389023,
        "남성_매출_금액": 11826904,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 2860484,
        "연령대_30_매출_금액": 2468746,
        "연령대_40_매출_금액": 6140707,
        "연령대_50_매출_금액": 9333289,
        "연령대_60_이상_매출_금액": 7412701
      },
      "id": "a8a4",
      "distance": 1.977741631355437
    },
    {
      "상권_코드_명": "석촌역 7번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "석촌동",
      "경도": 127.10161833772672,
      "위도": 37.5054062634517,
      "매출액": {
        "여성_매출_금액": 70504693,
        "남성_매출_금액": 61150694,
        "연령대_10_매출_금액": 200161,
        "연령대_20_매출_금액": 4534698,
        "연령대_30_매출_금액": 19806579,
        "연령대_40_매출_금액": 29440482,
        "연령대_50_매출_금액": 46425288,
        "연령대_60_이상_매출_금액": 31248179
      },
      "id": "b367",
      "distance": 2.007169445659227
    },
    {
      "상권_코드_명": "방이시장",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "방이2동",
      "경도": 127.11552676175948,
      "위도": 37.51106079756516,
      "매출액": {
        "여성_매출_금액": 63500121,
        "남성_매출_금액": 39146840,
        "연령대_10_매출_금액": 402548,
        "연령대_20_매출_금액": 21934601,
        "연령대_30_매출_금액": 28969305,
        "연령대_40_매출_금액": 20512592,
        "연령대_50_매출_금액": 22226183,
        "연령대_60_이상_매출_금액": 8601732
      },
      "id": "40e0",
      "distance": 2.011762876739983
    },
    {
      "상권_코드_명": "송파나루역 1번(송리단길)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "송파1동",
      "경도": 127.10820636509024,
      "위도": 37.509382852628754,
      "매출액": {
        "여성_매출_금액": 258509363,
        "남성_매출_금액": 99987101,
        "연령대_10_매출_금액": 2353781,
        "연령대_20_매출_금액": 122153666,
        "연령대_30_매출_금액": 110925967,
        "연령대_40_매출_금액": 43244087,
        "연령대_50_매출_금액": 47522915,
        "연령대_60_이상_매출_금액": 32296047
      },
      "id": "ef50",
      "distance": 2.0162991747375973
    },
    {
      "상권_코드_명": "방이역 4번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "방이1동",
      "경도": 127.12279974688528,
      "위도": 37.51121564107836,
      "매출액": {
        "여성_매출_금액": 74525365,
        "남성_매출_금액": 56910695,
        "연령대_10_매출_금액": 169930,
        "연령대_20_매출_금액": 7356398,
        "연령대_30_매출_금액": 22344788,
        "연령대_40_매출_금액": 31508389,
        "연령대_50_매출_금액": 34783036,
        "연령대_60_이상_매출_금액": 35273519
      },
      "id": "4c46",
      "distance": 2.0538241885369732
    },
    {
      "상권_코드_명": "벌말어린이공원",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "오금동",
      "경도": 127.13867447153532,
      "위도": 37.50217000650291,
      "매출액": {
        "여성_매출_금액": 10458482,
        "남성_매출_금액": 9854989,
        "연령대_10_매출_금액": 99159,
        "연령대_20_매출_금액": 950162,
        "연령대_30_매출_금액": 2561331,
        "연령대_40_매출_금액": 9638225,
        "연령대_50_매출_금액": 3596153,
        "연령대_60_이상_매출_금액": 3468441
      },
      "id": "319b",
      "distance": 2.063951216359596
    },
    {
      "상권_코드_명": "오동나무공원(송파레미니스1단지)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "오금동",
      "경도": 127.13453196048948,
      "위도": 37.50662576054443,
      "매출액": {
        "여성_매출_금액": 21327019,
        "남성_매출_금액": 11429209,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 4684182,
        "연령대_30_매출_금액": 1801484,
        "연령대_40_매출_금액": 9864503,
        "연령대_50_매출_금액": 10052185,
        "연령대_60_이상_매출_금액": 6353874
      },
      "id": "b64f",
      "distance": 2.0789698511229115
    },
    {
      "상권_코드_명": "석촌고분역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "석촌동",
      "경도": 127.09704648858848,
      "위도": 37.5033197760243,
      "매출액": {
        "여성_매출_금액": 5309113,
        "남성_매출_금액": 6432135,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 3024698,
        "연령대_30_매출_금액": 2936749,
        "연령대_40_매출_금액": 3592520,
        "연령대_50_매출_금액": 1485078,
        "연령대_60_이상_매출_금액": 702203
      },
      "id": "8e1a",
      "distance": 2.189689025382843
    },
    {
      "상권_코드_명": "한성백제역 3번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "방이2동",
      "경도": 127.11767970969709,
      "위도": 37.5135634626904,
      "매출액": {
        "여성_매출_금액": 41916857,
        "남성_매출_금액": 53295090,
        "연령대_10_매출_금액": 409908,
        "연령대_20_매출_금액": 6427923,
        "연령대_30_매출_금액": 10214658,
        "연령대_40_매출_금액": 18354559,
        "연령대_50_매출_금액": 33217747,
        "연령대_60_이상_매출_금액": 26587152
      },
      "id": "33a9",
      "distance": 2.2760975332886555
    },
    {
      "상권_코드_명": "거여역 1번(거여공원)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "거여1동",
      "경도": 127.14357306164348,
      "위도": 37.49713654406891,
      "매출액": {
        "여성_매출_금액": 108798859,
        "남성_매출_금액": 79436523,
        "연령대_10_매출_금액": 1608162,
        "연령대_20_매출_금액": 33006824,
        "연령대_30_매출_금액": 35379629,
        "연령대_40_매출_금액": 44105048,
        "연령대_50_매출_금액": 49852673,
        "연령대_60_이상_매출_금액": 24283046
      },
      "id": "e26c",
      "distance": 2.2776234002201337
    },
    {
      "상권_코드_명": "석촌고분역 4번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "삼전동",
      "경도": 127.09387561308928,
      "위도": 37.499943567584296,
      "매출액": {
        "여성_매출_금액": 26341620,
        "남성_매출_금액": 24666724,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 2061544,
        "연령대_30_매출_금액": 11170349,
        "연령대_40_매출_금액": 16794321,
        "연령대_50_매출_금액": 9465478,
        "연령대_60_이상_매출_금액": 11516652
      },
      "id": "736f",
      "distance": 2.2820971318793704
    },
    {
      "상권_코드_명": "거여역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "거여2동",
      "경도": 127.1455437075945,
      "위도": 37.49283633341059,
      "매출액": {
        "여성_매출_금액": 238501208,
        "남성_매출_금액": 191195028,
        "연령대_10_매출_금액": 4374833,
        "연령대_20_매출_금액": 49200175,
        "연령대_30_매출_금액": 91802060,
        "연령대_40_매출_금액": 111339534,
        "연령대_50_매출_금액": 118925927,
        "연령대_60_이상_매출_금액": 54053706
      },
      "id": "d2ec",
      "distance": 2.4070451954725542
    },
    {
      "상권_코드_명": "석촌고분역 1번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "삼전동",
      "경도": 127.09397230648412,
      "위도": 37.50490803067036,
      "매출액": {
        "여성_매출_금액": 251256448,
        "남성_매출_금액": 198686076,
        "연령대_10_매출_금액": 995756,
        "연령대_20_매출_금액": 44139665,
        "연령대_30_매출_금액": 68196309,
        "연령대_40_매출_금액": 106006199,
        "연령대_50_매출_금액": 152511709,
        "연령대_60_이상_매출_금액": 78092886
      },
      "id": "d019",
      "distance": 2.5131646642018293
    },
    {
      "상권_코드_명": "마천공원",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "마천2동",
      "경도": 127.14553646050464,
      "위도": 37.500756183807006,
      "매출액": {
        "여성_매출_금액": 11539068,
        "남성_매출_금액": 17270968,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 4710123,
        "연령대_30_매출_금액": 9383932,
        "연령대_40_매출_금액": 7939496,
        "연령대_50_매출_금액": 5586957,
        "연령대_60_이상_매출_금액": 1189528
      },
      "id": "7843",
      "distance": 2.552297554566107
    },
    {
      "상권_코드_명": "잠실 관광특구",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "방이2동",
      "경도": 127.1152409425314,
      "위도": 37.51643105790915,
      "매출액": {
        "여성_매출_금액": 1257779882,
        "남성_매출_금액": 571847610,
        "연령대_10_매출_금액": 3214652,
        "연령대_20_매출_금액": 250818190,
        "연령대_30_매출_금액": 368724279,
        "연령대_40_매출_금액": 522355333,
        "연령대_50_매출_금액": 360192457,
        "연령대_60_이상_매출_금액": 324322582
      },
      "id": "7d6a",
      "distance": 2.6080360427282563
    },
    {
      "상권_코드_명": "윗방죽마을공원",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강남구",
      "행정동_코드_명": "세곡동",
      "경도": 127.10388999835396,
      "위도": 37.47158947606483,
      "매출액": {
        "여성_매출_금액": 1974334,
        "남성_매출_금액": 15150003,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 385919,
        "연령대_30_매출_금액": 1802466,
        "연령대_40_매출_금액": 3715031,
        "연령대_50_매출_금액": 8398669,
        "연령대_60_이상_매출_금액": 2822252
      },
      "id": "f880",
      "distance": 2.7072088636488094
    },
    {
      "상권_코드_명": "개미어린이공원",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "거여2동",
      "경도": 127.14898998707608,
      "위도": 37.491516567954285,
      "매출액": {
        "여성_매출_금액": 5463437,
        "남성_매출_금액": 8850534,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 1291512,
        "연령대_30_매출_금액": 1324234,
        "연령대_40_매출_금액": 3646021,
        "연령대_50_매출_금액": 3546837,
        "연령대_60_이상_매출_금액": 4505367
      },
      "id": "0622",
      "distance": 2.7166464642129386
    },
    {
      "상권_코드_명": "잠실역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "잠실6동",
      "경도": 127.10126801274058,
      "위도": 37.51398412500385,
      "매출액": {
        "여성_매출_금액": 1327871543,
        "남성_매출_금액": 642906222,
        "연령대_10_매출_금액": 3973110,
        "연령대_20_매출_금액": 250815943,
        "연령대_30_매출_금액": 374726420,
        "연령대_40_매출_금액": 585265121,
        "연령대_50_매출_금액": 400920469,
        "연령대_60_이상_매출_금액": 355076703
      },
      "id": "12f2",
      "distance": 2.764144185911855
    },
    {
      "상권_코드_명": "삼전역 3번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "삼전동",
      "경도": 127.08868660012052,
      "위도": 37.50146126676753,
      "매출액": {
        "여성_매출_금액": 82055563,
        "남성_매출_금액": 57347667,
        "연령대_10_매출_금액": 1296579,
        "연령대_20_매출_금액": 13819673,
        "연령대_30_매출_금액": 44690591,
        "연령대_40_매출_금액": 41467216,
        "연령대_50_매출_금액": 28149179,
        "연령대_60_이상_매출_금액": 9979992
      },
      "id": "9ae5",
      "distance": 2.769933097366966
    },
    {
      "상권_코드_명": "남천초등학교",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "마천2동",
      "경도": 127.14893749244364,
      "위도": 37.49924726592884,
      "매출액": {
        "여성_매출_금액": 138912700,
        "남성_매출_금액": 115268434,
        "연령대_10_매출_금액": 18246594,
        "연령대_20_매출_금액": 30128859,
        "연령대_30_매출_금액": 23154944,
        "연령대_40_매출_금액": 46868731,
        "연령대_50_매출_금액": 69036968,
        "연령대_60_이상_매출_금액": 66745038
      },
      "id": "31ec",
      "distance": 2.7911819069339083
    },
    {
      "상권_코드_명": "마천중앙시장",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "마천2동",
      "경도": 127.1511289864303,
      "위도": 37.49804614532687,
      "매출액": {
        "여성_매출_금액": 19922153,
        "남성_매출_금액": 13878100,
        "연령대_10_매출_금액": 202261,
        "연령대_20_매출_금액": 5366647,
        "연령대_30_매출_금액": 8043160,
        "연령대_40_매출_금액": 5033219,
        "연령대_50_매출_금액": 10155203,
        "연령대_60_이상_매출_금액": 4999763
      },
      "id": "e0c8",
      "distance": 2.9512443234990893
    },
    {
      "상권_코드_명": "대청초등학교",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강남구",
      "행정동_코드_명": "일원1동",
      "경도": 127.084592799527,
      "위도": 37.49154418873969,
      "매출액": {
        "여성_매출_금액": 198457167,
        "남성_매출_금액": 194282487,
        "연령대_10_매출_금액": 4028625,
        "연령대_20_매출_금액": 39754699,
        "연령대_30_매출_금액": 79589807,
        "연령대_40_매출_금액": 119066395,
        "연령대_50_매출_금액": 108040299,
        "연령대_60_이상_매출_금액": 42259828
      },
      "id": "aff2",
      "distance": 2.975590890144295
    },
    {
      "상권_코드_명": "마천역(마천초등학교)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "마천1동",
      "경도": 127.15239139655954,
      "위도": 37.495999240540726,
      "매출액": {
        "여성_매출_금액": 74865624,
        "남성_매출_금액": 83167678,
        "연령대_10_매출_금액": 1030445,
        "연령대_20_매출_금액": 4038178,
        "연령대_30_매출_금액": 17996562,
        "연령대_40_매출_금액": 60607052,
        "연령대_50_매출_금액": 37619795,
        "연령대_60_이상_매출_금액": 36741268
      },
      "id": "a4c6",
      "distance": 3.0281607213598996
    },
    {
      "상권_코드_명": "삼전역 1번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "잠실본동",
      "경도": 127.08515279573976,
      "위도": 37.50671672745682,
      "매출액": {
        "여성_매출_금액": 134909169,
        "남성_매출_금액": 79601385,
        "연령대_10_매출_금액": 3724267,
        "연령대_20_매출_금액": 26973940,
        "연령대_30_매출_금액": 47286231,
        "연령대_40_매출_금액": 64313397,
        "연령대_50_매출_금액": 37973843,
        "연령대_60_이상_매출_금액": 34238876
      },
      "id": "e7ac",
      "distance": 3.290015877030551
    },
    {
      "상권_코드_명": "잠실나루역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "잠실4동",
      "경도": 127.10435448058152,
      "위도": 37.52106332251792,
      "매출액": {
        "여성_매출_금액": 92440038,
        "남성_매출_금액": 72284481,
        "연령대_10_매출_금액": 564601,
        "연령대_20_매출_금액": 9585266,
        "연령대_30_매출_금액": 28759026,
        "연령대_40_매출_금액": 65535586,
        "연령대_50_매출_금액": 38542376,
        "연령대_60_이상_매출_금액": 21737664
      },
      "id": "d6e3",
      "distance": 3.3427329148123883
    },
    {
      "상권_코드_명": "삼전역 4번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "잠실본동",
      "경도": 127.0824809580479,
      "위도": 37.504276899620265,
      "매출액": {
        "여성_매출_금액": 37613441,
        "남성_매출_금액": 40788892,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 3399004,
        "연령대_30_매출_금액": 14332244,
        "연령대_40_매출_금액": 19182158,
        "연령대_50_매출_금액": 22765342,
        "연령대_60_이상_매출_금액": 18723583
      },
      "id": "8077",
      "distance": 3.3924913428173884
    },
    {
      "상권_코드_명": "새마을시장",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "잠실본동",
      "경도": 127.08521187520329,
      "위도": 37.50894216638436,
      "매출액": {
        "여성_매출_금액": 287249009,
        "남성_매출_금액": 111116146,
        "연령대_10_매출_금액": 1965776,
        "연령대_20_매출_금액": 51674437,
        "연령대_30_매출_금액": 59162703,
        "연령대_40_매출_금액": 80929254,
        "연령대_50_매출_금액": 64843072,
        "연령대_60_이상_매출_금액": 139789912
      },
      "id": "af23",
      "distance": 3.406488657589927
    },
    {
      "상권_코드_명": "둔촌동역 3번(성내3동주민센터)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "성내3동",
      "경도": 127.13163389250457,
      "위도": 37.5243968073635,
      "매출액": {
        "여성_매출_금액": 26671584,
        "남성_매출_금액": 11325257,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 1241129,
        "연령대_30_매출_금액": 3526129,
        "연령대_40_매출_금액": 11189473,
        "연령대_50_매출_금액": 14460558,
        "연령대_60_이상_매출_금액": 7579552
      },
      "id": "65dc",
      "distance": 3.674552714299469
    },
    {
      "상권_코드_명": "잠실새내역(신천)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "잠실본동",
      "경도": 127.0825782728224,
      "위도": 37.51048475437836,
      "매출액": {
        "여성_매출_금액": 2101434238,
        "남성_매출_금액": 1099901315,
        "연령대_10_매출_금액": 18653901,
        "연령대_20_매출_금액": 495494341,
        "연령대_30_매출_금액": 815354208,
        "연령대_40_매출_금액": 970025281,
        "연령대_50_매출_금액": 676312326,
        "연령대_60_이상_매출_금액": 225495495
      },
      "id": "9120",
      "distance": 3.694108460559832
    },
    {
      "상권_코드_명": "성내천어린이공원(하니사랑길)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "성내1동",
      "경도": 127.12533575007856,
      "위도": 37.526187642325176,
      "매출액": {
        "여성_매출_금액": 9140493,
        "남성_매출_금액": 19826820,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 1726592,
        "연령대_30_매출_금액": 9969861,
        "연령대_40_매출_금액": 10826191,
        "연령대_50_매출_금액": 4005176,
        "연령대_60_이상_매출_금액": 2439493
      },
      "id": "655b",
      "distance": 3.731780503263132
    },
    {
      "상권_코드_명": "둔촌역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "성내3동",
      "경도": 127.13491805500612,
      "위도": 37.52633926481791,
      "매출액": {
        "여성_매출_금액": 240306662,
        "남성_매출_금액": 280131456,
        "연령대_10_매출_금액": 7061777,
        "연령대_20_매출_금액": 91113314,
        "연령대_30_매출_금액": 136629248,
        "연령대_40_매출_금액": 121990289,
        "연령대_50_매출_금액": 116544293,
        "연령대_60_이상_매출_금액": 47099196
      },
      "id": "ee78",
      "distance": 3.9773770257700476
    },
    {
      "상권_코드_명": "둔촌동역 4번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "성내3동",
      "경도": 127.13232964353004,
      "위도": 37.52761260530839,
      "매출액": {
        "여성_매출_금액": 28400160,
        "남성_매출_금액": 21652465,
        "연령대_10_매출_금액": 629325,
        "연령대_20_매출_금액": 4152361,
        "연령대_30_매출_금액": 10260531,
        "연령대_40_매출_금액": 12692068,
        "연령대_50_매출_금액": 13288940,
        "연령대_60_이상_매출_금액": 9029400
      },
      "id": "20ca",
      "distance": 4.033300795740052
    },
    {
      "상권_코드_명": "강동구청역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "성내1동",
      "경도": 127.12268220880004,
      "위도": 37.52923581309821,
      "매출액": {
        "여성_매출_금액": 32497554,
        "남성_매출_금액": 29112921,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 2760030,
        "연령대_30_매출_금액": 8535827,
        "연령대_40_매출_금액": 17145510,
        "연령대_50_매출_금액": 18769211,
        "연령대_60_이상_매출_금액": 14399897
      },
      "id": "9d60",
      "distance": 4.0370661759184046
    },
    {
      "상권_코드_명": "둔촌역전통시장",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "성내3동",
      "경도": 127.13426453864876,
      "위도": 37.52780864175132,
      "매출액": {
        "여성_매출_금액": 16890562,
        "남성_매출_금액": 23651449,
        "연령대_10_매출_금액": 395968,
        "연령대_20_매출_금액": 5647293,
        "연령대_30_매출_금액": 5184977,
        "연령대_40_매출_금액": 7725253,
        "연령대_50_매출_금액": 11338846,
        "연령대_60_이상_매출_금액": 10249674
      },
      "id": "a58e",
      "distance": 4.109493624553864
    },
    {
      "상권_코드_명": "강남개포시장",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강남구",
      "행정동_코드_명": "개포2동",
      "경도": 127.06759496436574,
      "위도": 37.48889716485464,
      "매출액": {
        "여성_매출_금액": 225015095,
        "남성_매출_금액": 183219515,
        "연령대_10_매출_금액": 5586236,
        "연령대_20_매출_금액": 41922796,
        "연령대_30_매출_금액": 42002595,
        "연령대_40_매출_금액": 114652876,
        "연령대_50_매출_금액": 139468552,
        "연령대_60_이상_매출_금액": 64601555
      },
      "id": "7fb3",
      "distance": 4.494644616850413
    },
    {
      "상권_코드_명": "강동구립성내도서관",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "성내3동",
      "경도": 127.1349847993474,
      "위도": 37.53198846491348,
      "매출액": {
        "여성_매출_금액": 24887563,
        "남성_매출_금액": 24007136,
        "연령대_10_매출_금액": 312619,
        "연령대_20_매출_금액": 3509460,
        "연령대_30_매출_금액": 10614774,
        "연령대_40_매출_금액": 9412566,
        "연령대_50_매출_금액": 9698224,
        "연령대_60_이상_매출_금액": 15347056
      },
      "id": "41cf",
      "distance": 4.568896113951449
    },
    {
      "상권_코드_명": "성내전통시장",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "성내2동",
      "경도": 127.12749791159769,
      "위도": 37.53365462601447,
      "매출액": {
        "여성_매출_금액": 13493626,
        "남성_매출_금액": 9603025,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 743915,
        "연령대_30_매출_금액": 1436454,
        "연령대_40_매출_금액": 3284891,
        "연령대_50_매출_금액": 7484602,
        "연령대_60_이상_매출_금액": 10146789
      },
      "id": "168a",
      "distance": 4.582526768938494
    },
    {
      "상권_코드_명": "둔촌동역 1번(한산중학교)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "둔촌2동",
      "경도": 127.13970109005332,
      "위도": 37.53115405950385,
      "매출액": {
        "여성_매출_금액": 69796764,
        "남성_매출_금액": 31053117,
        "연령대_10_매출_금액": 414223,
        "연령대_20_매출_금액": 5260586,
        "연령대_30_매출_금액": 7007722,
        "연령대_40_매출_금액": 14732048,
        "연령대_50_매출_금액": 36784601,
        "연령대_60_이상_매출_금액": 36650701
      },
      "id": "f67f",
      "distance": 4.634778260781313
    },
    {
      "상권_코드_명": "강동역 4번(강풀만화거리)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "성내2동",
      "경도": 127.13032680682068,
      "위도": 37.533876788109865,
      "매출액": {
        "여성_매출_금액": 84874065,
        "남성_매출_금액": 67365203,
        "연령대_10_매출_금액": 987114,
        "연령대_20_매출_금액": 16038418,
        "연령대_30_매출_금액": 34564572,
        "연령대_40_매출_금액": 42224251,
        "연령대_50_매출_금액": 32623121,
        "연령대_60_이상_매출_금액": 25801792
      },
      "id": "bad8",
      "distance": 4.657434492051893
    },
    {
      "상권_코드_명": "천호역 6번",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "성내2동",
      "경도": 127.1243996374976,
      "위도": 37.53472111071503,
      "매출액": {
        "여성_매출_금액": 15457947,
        "남성_매출_금액": 16861677,
        "연령대_10_매출_금액": 233955,
        "연령대_20_매출_금액": 1878705,
        "연령대_30_매출_금액": 3195156,
        "연령대_40_매출_금액": 11633689,
        "연령대_50_매출_금액": 9177173,
        "연령대_60_이상_매출_금액": 6200946
      },
      "id": "8ff2",
      "distance": 4.6596840573484455
    },
    {
      "상권_코드_명": "둔촌고등학교(둔촌중학교)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "둔촌2동",
      "경도": 127.14483672836192,
      "위도": 37.53076044252061,
      "매출액": {
        "여성_매출_금액": 13881346,
        "남성_매출_금액": 4195377,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 3456785,
        "연령대_30_매출_금액": 4836916,
        "연령대_40_매출_금액": 5580344,
        "연령대_50_매출_금액": 2966909,
        "연령대_60_이상_매출_금액": 1235769
      },
      "id": "c1d7",
      "distance": 4.799059467334947
    },
    {
      "상권_코드_명": "풍납시장",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "송파구",
      "행정동_코드_명": "풍납1동",
      "경도": 127.1200819268998,
      "위도": 37.53741056029039,
      "매출액": {
        "여성_매출_금액": 109465110,
        "남성_매출_금액": 93064358,
        "연령대_10_매출_금액": 83738,
        "연령대_20_매출_금액": 29865528,
        "연령대_30_매출_금액": 54517522,
        "연령대_40_매출_금액": 29585877,
        "연령대_50_매출_금액": 58260718,
        "연령대_60_이상_매출_금액": 30216085
      },
      "id": "ea54",
      "distance": 4.929804410498121
    },
    {
      "상권_코드_명": "대치역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강남구",
      "행정동_코드_명": "대치1동",
      "경도": 127.06228493383824,
      "위도": 37.49418899631532,
      "매출액": {
        "여성_매출_금액": 159580022,
        "남성_매출_금액": 81720240,
        "연령대_10_매출_금액": 1874605,
        "연령대_20_매출_금액": 10129352,
        "연령대_30_매출_금액": 39209005,
        "연령대_40_매출_금액": 69816316,
        "연령대_50_매출_금액": 83106174,
        "연령대_60_이상_매출_금액": 37164809
      },
      "id": "b7d9",
      "distance": 4.940093685885478
    },
    {
      "상권_코드_명": "둔촌2동주민센터",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "둔촌2동",
      "경도": 127.14316767622354,
      "위도": 37.53356458912888,
      "매출액": {
        "여성_매출_금액": 39204652,
        "남성_매출_금액": 36706015,
        "연령대_10_매출_금액": 1861784,
        "연령대_20_매출_금액": 12642576,
        "연령대_30_매출_금액": 19327961,
        "연령대_40_매출_금액": 17614619,
        "연령대_50_매출_금액": 13739426,
        "연령대_60_이상_매출_금액": 10724300
      },
      "id": "d202",
      "distance": 5.0071049594580685
    },
    {
      "상권_코드_명": "강변역(테크노마트)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "광진구",
      "행정동_코드_명": "구의3동",
      "경도": 127.09463209799448,
      "위도": 37.5348117858326,
      "매출액": {
        "여성_매출_금액": 70344320,
        "남성_매출_금액": 70075561,
        "연령대_10_매출_금액": 1172077,
        "연령대_20_매출_금액": 14227550,
        "연령대_30_매출_금액": 35023847,
        "연령대_40_매출_금액": 36936683,
        "연령대_50_매출_금액": 32454081,
        "연령대_60_이상_매출_금액": 20605644
      },
      "id": "6598",
      "distance": 5.08499033924243
    },
    {
      "상권_코드_명": "은마아파트",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강남구",
      "행정동_코드_명": "대치4동",
      "경도": 127.06060379417536,
      "위도": 37.49884807441995,
      "매출액": {
        "여성_매출_금액": 208820573,
        "남성_매출_금액": 203859777,
        "연령대_10_매출_금액": 6305580,
        "연령대_20_매출_금액": 30822702,
        "연령대_30_매출_금액": 35062837,
        "연령대_40_매출_금액": 117109137,
        "연령대_50_매출_금액": 144559945,
        "연령대_60_이상_매출_금액": 78820149
      },
      "id": "f115",
      "distance": 5.126774573603578
    },
    {
      "상권_코드_명": "개포고등학교",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강남구",
      "행정동_코드_명": "개포2동",
      "경도": 127.06142798105036,
      "위도": 37.48338636262938,
      "매출액": {
        "여성_매출_금액": 100342374,
        "남성_매출_금액": 106678588,
        "연령대_10_매출_금액": 353084,
        "연령대_20_매출_금액": 10710380,
        "연령대_30_매출_금액": 25677119,
        "연령대_40_매출_금액": 65695133,
        "연령대_50_매출_금액": 58377988,
        "연령대_60_이상_매출_금액": 46207258
      },
      "id": "e527",
      "distance": 5.129561858394302
    },
    {
      "상권_코드_명": "성동초등학교",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "광진구",
      "행정동_코드_명": "자양2동",
      "경도": 127.0881011638724,
      "위도": 37.53257334690112,
      "매출액": {
        "여성_매출_금액": 7231298,
        "남성_매출_금액": 5487452,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 1133244,
        "연령대_30_매출_금액": 3050139,
        "연령대_40_매출_금액": 3156660,
        "연령대_50_매출_금액": 1646687,
        "연령대_60_이상_매출_금액": 3732020
      },
      "id": "303a",
      "distance": 5.132575525562102
    },
    {
      "상권_코드_명": "길동역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "길동",
      "경도": 127.13829670196402,
      "위도": 37.53647161403156,
      "매출액": {
        "여성_매출_금액": 155280214,
        "남성_매출_금액": 130277995,
        "연령대_10_매출_금액": 2359477,
        "연령대_20_매출_금액": 65609153,
        "연령대_30_매출_금액": 111970047,
        "연령대_40_매출_금액": 62559026,
        "연령대_50_매출_금액": 35380093,
        "연령대_60_이상_매출_금액": 7680413
      },
      "id": "662c",
      "distance": 5.136292298275571
    },
    {
      "상권_코드_명": "성자초등학교",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "광진구",
      "행정동_코드_명": "자양2동",
      "경도": 127.0843654670054,
      "위도": 37.53069298250582,
      "매출액": {
        "여성_매출_금액": 28582429,
        "남성_매출_금액": 33962022,
        "연령대_10_매출_금액": 691482,
        "연령대_20_매출_금액": 9283714,
        "연령대_30_매출_금액": 14809191,
        "연령대_40_매출_금액": 14691443,
        "연령대_50_매출_금액": 16192579,
        "연령대_60_이상_매출_금액": 6876042
      },
      "id": "586f",
      "distance": 5.139402077605955
    },
    {
      "상권_코드_명": "중앙보훈병원",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "둔촌2동",
      "경도": 127.14759082543831,
      "위도": 37.53324379403351,
      "매출액": {
        "여성_매출_금액": 2969201,
        "남성_매출_금액": 975988,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 412389,
        "연령대_30_매출_금액": 0,
        "연령대_40_매출_금액": 1044719,
        "연령대_50_매출_금액": 1580825,
        "연령대_60_이상_매출_금액": 907256
      },
      "id": "b740",
      "distance": 5.15921829285584
    },
    {
      "상권_코드_명": "삼성역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강남구",
      "행정동_코드_명": "대치2동",
      "경도": 127.06315654228575,
      "위도": 37.508667696206736,
      "매출액": {
        "여성_매출_금액": 106412320,
        "남성_매출_금액": 64291923,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 14443779,
        "연령대_30_매출_금액": 48923673,
        "연령대_40_매출_금액": 39973188,
        "연령대_50_매출_금액": 48860735,
        "연령대_60_이상_매출_금액": 18502868
      },
      "id": "99ae",
      "distance": 5.160277289164245
    },
    {
      "상권_코드_명": "로데오거리상점가",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "천호2동",
      "경도": 127.12704340647122,
      "위도": 37.53917824570736,
      "매출액": {
        "여성_매출_금액": 159104445,
        "남성_매출_금액": 127282126,
        "연령대_10_매출_금액": 3079504,
        "연령대_20_매출_금액": 80872955,
        "연령대_30_매출_금액": 119326498,
        "연령대_40_매출_금액": 47495331,
        "연령대_50_매출_금액": 17525873,
        "연령대_60_이상_매출_금액": 18086410
      },
      "id": "ff60",
      "distance": 5.181946216411821
    },
    {
      "상권_코드_명": "천호역",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "천호2동",
      "경도": 127.12444156010652,
      "위도": 37.53952339599033,
      "매출액": {
        "여성_매출_금액": 352310473,
        "남성_매출_금액": 221755394,
        "연령대_10_매출_금액": 1598637,
        "연령대_20_매출_금액": 101503298,
        "연령대_30_매출_금액": 168515870,
        "연령대_40_매출_금액": 130168976,
        "연령대_50_매출_금액": 105162070,
        "연령대_60_이상_매출_금액": 67117016
      },
      "id": "97eb",
      "distance": 5.190814595306781
    },
    {
      "상권_코드_명": "자양동우체국",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "광진구",
      "행정동_코드_명": "자양2동",
      "경도": 127.0807217358998,
      "위도": 37.52999274825613,
      "매출액": {
        "여성_매출_금액": 58238332,
        "남성_매출_금액": 52083107,
        "연령대_10_매출_금액": 215937,
        "연령대_20_매출_금액": 3309255,
        "연령대_30_매출_금액": 22904616,
        "연령대_40_매출_금액": 36027187,
        "연령대_50_매출_금액": 18619591,
        "연령대_60_이상_매출_금액": 29244853
      },
      "id": "9817",
      "distance": 5.271976137445868
    },
    {
      "상권_코드_명": "구남초등학교",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "광진구",
      "행정동_코드_명": "구의3동",
      "경도": 127.09089919867608,
      "위도": 37.53546343842295,
      "매출액": {
        "여성_매출_금액": 9671962,
        "남성_매출_금액": 10990865,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 321684,
        "연령대_30_매출_금액": 2648531,
        "연령대_40_매출_금액": 2948769,
        "연령대_50_매출_금액": 7505957,
        "연령대_60_이상_매출_금액": 7237886
      },
      "id": "fc9c",
      "distance": 5.292951988293514
    },
    {
      "상권_코드_명": "천호역 1번(천호문구완구거리)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "천호2동",
      "경도": 127.12132089509709,
      "위도": 37.54091418243181,
      "매출액": {
        "여성_매출_금액": 5216832,
        "남성_매출_금액": 3524569,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 350123,
        "연령대_30_매출_금액": 466830,
        "연령대_40_매출_금액": 2976044,
        "연령대_50_매출_금액": 2474202,
        "연령대_60_이상_매출_금액": 2474202
      },
      "id": "bc92",
      "distance": 5.323614651720761
    },
    {
      "상권_코드_명": "강동구립 천호도서관",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "천호3동",
      "경도": 127.13228380422072,
      "위도": 37.54009151114284,
      "매출액": {
        "여성_매출_금액": 48199732,
        "남성_매출_금액": 39287176,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 3290510,
        "연령대_30_매출_금액": 3607851,
        "연령대_40_매출_금액": 15298556,
        "연령대_50_매출_금액": 36569537,
        "연령대_60_이상_매출_금액": 28720454
      },
      "id": "d675",
      "distance": 5.3696363426304705
    },
    {
      "상권_코드_명": "길동주민센터(강동도서관)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "길동",
      "경도": 127.14326513418864,
      "위도": 37.537195500867774,
      "매출액": {
        "여성_매출_금액": 122792939,
        "남성_매출_금액": 75947460,
        "연령대_10_매출_금액": 450058,
        "연령대_20_매출_금액": 19065675,
        "연령대_30_매출_금액": 40337694,
        "연령대_40_매출_금액": 36176316,
        "연령대_50_매출_금액": 61035025,
        "연령대_60_이상_매출_금액": 41675630
      },
      "id": "2fe2",
      "distance": 5.376335744558726
    },
    {
      "상권_코드_명": "대치사거리",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강남구",
      "행정동_코드_명": "대치4동",
      "경도": 127.05841315411668,
      "위도": 37.503038855171134,
      "매출액": {
        "여성_매출_금액": 148931477,
        "남성_매출_금액": 161044657,
        "연령대_10_매출_금액": 10195423,
        "연령대_20_매출_금액": 26045836,
        "연령대_30_매출_금액": 56376995,
        "연령대_40_매출_금액": 145072194,
        "연령대_50_매출_금액": 59315205,
        "연령대_60_이상_매출_금액": 12970481
      },
      "id": "9f9b",
      "distance": 5.394318461403113
    },
    {
      "상권_코드_명": "도곡초등학교",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강남구",
      "행정동_코드_명": "대치4동",
      "경도": 127.05662399395344,
      "위도": 37.50003036704142,
      "매출액": {
        "여성_매출_금액": 45666198,
        "남성_매출_금액": 27716686,
        "연령대_10_매출_금액": 930768,
        "연령대_20_매출_금액": 7848015,
        "연령대_30_매출_금액": 7300374,
        "연령대_40_매출_금액": 14539508,
        "연령대_50_매출_금액": 21708645,
        "연령대_60_이상_매출_금액": 21055575
      },
      "id": "b68f",
      "distance": 5.492172074173162
    },
    {
      "상권_코드_명": "강남 마이스 관광특구",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강남구",
      "행정동_코드_명": "삼성1동",
      "경도": 127.05974276727348,
      "위도": 37.51108416413466,
      "매출액": {
        "여성_매출_금액": 212856785,
        "남성_매출_금액": 176023905,
        "연령대_10_매출_금액": 508288,
        "연령대_20_매출_금액": 40851219,
        "연령대_30_매출_금액": 90654156,
        "연령대_40_매출_금액": 106470669,
        "연령대_50_매출_금액": 110933427,
        "연령대_60_이상_매출_금액": 39462930
      },
      "id": "13fe",
      "distance": 5.536127680871446
    },
    {
      "상권_코드_명": "천일초등학교",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "천호3동",
      "경도": 127.1340061327874,
      "위도": 37.54145908808072,
      "매출액": {
        "여성_매출_금액": 15186915,
        "남성_매출_금액": 11663552,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 0,
        "연령대_30_매출_금액": 971963,
        "연령대_40_매출_금액": 4009346,
        "연령대_50_매출_금액": 0,
        "연령대_60_이상_매출_금액": 21869158
      },
      "id": "dbe5",
      "distance": 5.55374225615376
    },
    {
      "상권_코드_명": "구삼강변맛길",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "광진구",
      "행정동_코드_명": "구의3동",
      "경도": 127.09266847748852,
      "위도": 37.53889487383089,
      "매출액": {
        "여성_매출_금액": 227750237,
        "남성_매출_금액": 167099810,
        "연령대_10_매출_금액": 5095890,
        "연령대_20_매출_금액": 82513241,
        "연령대_30_매출_금액": 101174884,
        "연령대_40_매출_금액": 93692656,
        "연령대_50_매출_금액": 78192600,
        "연령대_60_이상_매출_금액": 34180775
      },
      "id": "e858",
      "distance": 5.5701525948875465
    },
    {
      "상권_코드_명": "길동복조리시장",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "길동",
      "경도": 127.14358543114432,
      "위도": 37.53901513097588,
      "매출액": {
        "여성_매출_금액": 37209173,
        "남성_매출_금액": 19122616,
        "연령대_10_매출_금액": 224023,
        "연령대_20_매출_금액": 3051491,
        "연령대_30_매출_금액": 5085559,
        "연령대_40_매출_금액": 21145386,
        "연령대_50_매출_금액": 12799434,
        "연령대_60_이상_매출_금액": 14025896
      },
      "id": "2cb9",
      "distance": 5.5727363314065395
    },
    {
      "상권_코드_명": "자양한강도서관",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "광진구",
      "행정동_코드_명": "자양2동",
      "경도": 127.07707997341755,
      "위도": 37.5311394528356,
      "매출액": {
        "여성_매출_금액": 34867554,
        "남성_매출_금액": 37962501,
        "연령대_10_매출_금액": 939764,
        "연령대_20_매출_금액": 17817335,
        "연령대_30_매출_금액": 13638092,
        "연령대_40_매출_금액": 17201167,
        "연령대_50_매출_금액": 18841787,
        "연령대_60_이상_매출_금액": 4391909
      },
      "id": "673c",
      "distance": 5.575515612192135
    },
    {
      "상권_코드_명": "고분다리전통시장",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "천호3동",
      "경도": 127.13319294571788,
      "위도": 37.54230694723064,
      "매출액": {
        "여성_매출_금액": 52817292,
        "남성_매출_금액": 7726340,
        "연령대_10_매출_금액": 3722130,
        "연령대_20_매출_금액": 1802356,
        "연령대_30_매출_금액": 2610351,
        "연령대_40_매출_금액": 13946691,
        "연령대_50_매출_금액": 24383925,
        "연령대_60_이상_매출_금액": 14078179
      },
      "id": "a115",
      "distance": 5.627861761421811
    },
    {
      "상권_코드_명": "천호지구대(천호동자전거거리)",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "천호2동",
      "경도": 127.12347517955996,
      "위도": 37.54358791690794,
      "매출액": {
        "여성_매출_금액": 13595505,
        "남성_매출_금액": 9800563,
        "연령대_10_매출_금액": 82316,
        "연령대_20_매출_금액": 894499,
        "연령대_30_매출_금액": 3019021,
        "연령대_40_매출_금액": 5558921,
        "연령대_50_매출_금액": 5445634,
        "연령대_60_이상_매출_금액": 8395677
      },
      "id": "df39",
      "distance": 5.632873760776405
    },
    {
      "상권_코드_명": "GS강동자이아파트",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "강동구",
      "행정동_코드_명": "길동",
      "경도": 127.14713686672866,
      "위도": 37.538289959838245,
      "매출액": {
        "여성_매출_금액": 33983611,
        "남성_매출_금액": 43221849,
        "연령대_10_매출_금액": 0,
        "연령대_20_매출_금액": 9906209,
        "연령대_30_매출_금액": 6426440,
        "연령대_40_매출_금액": 18639998,
        "연령대_50_매출_금액": 33253310,
        "연령대_60_이상_매출_금액": 8979503
      },
      "id": "0128",
      "distance": 5.63345528382027
    },
    {
      "상권_코드_명": "광진정말공원",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "광진구",
      "행정동_코드_명": "자양1동",
      "경도": 127.0789713956622,
      "위도": 37.53307535534298,
      "매출액": {
        "여성_매출_금액": 184937739,
        "남성_매출_금액": 136968373,
        "연령대_10_매출_금액": 1332806,
        "연령대_20_매출_금액": 38377111,
        "연령대_30_매출_금액": 74196504,
        "연령대_40_매출_금액": 72555303,
        "연령대_50_매출_금액": 79304100,
        "연령대_60_이상_매출_금액": 56140289
      },
      "id": "889a",
      "distance": 5.636427799824925
    },
    {
      "상권_코드_명": "올림픽대교북단",
      "서비스_업종_코드_명": "미용실",
      "기준_년분기_코드": 20221,
      "자치구_코드_명": "광진구",
      "행정동_코드_명": "구의3동",
      "경도": 127.09581633739666,
      "위도": 37.5407213910826,
      "매출액": {
        "여성_매출_금액": 52743230,
        "남성_매출_금액": 37125718,
        "연령대_10_매출_금액": 2914111,
        "연령대_20_매출_금액": 7722753,
        "연령대_30_매출_금액": 15814671,
        "연령대_40_매출_금액": 34573051,
        "연령대_50_매출_금액": 24030312,
        "연령대_60_이상_매출_금액": 4814050
      },
      "id": "0f0a",
      "distance": 5.653304560075528
    }
  ]
}

# %%
len(sam['data'])
# Out:
# 100

# %%
df = pd.read_csv('../data/only_store.csv', index_col=0)

# %%
df.head()
# Out:
#   상권_구분_코드 상권_구분_코드_명    상권_코드          상권_코드_명  엑스좌표_값  와이좌표_값  자치구_코드  \
# 0        A       골목상권  3110008  배화여자대학교(박노수미술관)  197093  453418   11110
# 1        A       골목상권  3110009            자하문터널  196991  455057   11110
# 2        A       골목상권  3110010            평창동서측  197064  456643   11110
# 3        A       골목상권  3110017            정독도서관  198581  453781   11110
# 4        A       골목상권  3110018           중앙고등학교  198883  453690   11110
#
#   자치구_코드_명    행정동_코드 행정동_코드_명   영역_면적          경도         위도
# 0      종로구  11110515    청운효자동  149264  126.967090  37.580309
# 1      종로구  11110550      부암동  178306  126.965928  37.595076
# 2      종로구  11110560      평창동  369415  126.966748  37.609366
# 3      종로구  11110600      가회동   83855  126.983935  37.583584
# 4      종로구  11110600      가회동  166872  126.987354  37.582764

# %%
import numpy as np

# %%
def haversine(lat1, lon1, lat2, lon2):
    # 모든 위도 경도는 라디안 단위로 변환
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    # 위도와 경도 차이
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    # 허버사인 공식 사용
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    
    # 6,371km는 지구의 반지름
    km = 6371 * c
    return km

# %%
import requests

# %%
def get_location(address):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json'
    headers = {
    "Authorization": f"KakaoAK {REST_API_KEY}"
    }
    response = requests.get(url, headers=headers, params={'query': address}).json()

    long = response['documents'][0]['x'] 
    lati = response['documents'][0]['y']
    return float(lati), float(long)

# %%
lati, long = get_location('가락시장역')

# %%
df['distance'] = df.apply(lambda row: haversine(lati, long, row['위도'], row['경도']), axis=1)
df_sorted = df.sort_values(by='distance').head(100)

# %%
df_sorted.columns
# Out:
# Index(['상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명', '엑스좌표_값', '와이좌표_값',
#        '자치구_코드', '자치구_코드_명', '행정동_코드', '행정동_코드_명', '영역_면적', '경도', '위도',
#        'distance'],
#       dtype='object')

# %%
df_sorted['상권_코드_명'].unique()
# Out:
# array(['가락시장역', '경찰병원역 4번(건너말공원)', '경찰병원역', '문정동 로데오거리 상점가(문정동 로데오거리)',
#        '가락시장', '경찰병원역 3번', '문정역 1번', '문정역', '문정초등학교', '송파역 2번', '오금역 4번',
#        '송파사거리(송파역)', '오금역', '문정역 2번', '석촌중학교(방이육교)', '석촌시장',
#        '장지동주민센터(한림연예예술고교)', '문정동성당', '수서역', '개롱역', '문현중학교(장지역 1번)',
#        '석촌역 6번', '석촌역 3번', '방이동고분군(방산고등학교)', '송파책박물관', '투구봉어린이공원',
#        '장지역(가든파이브)', '석촌고분역 3번', '석촌역(석촌호수)', '방이역 2번', '송파나루역 3번',
#        '오금공원(오주중학교)', '방이역', '송파나루역', '보인중학교', '석촌역 7번', '방이시장',
#        '송파나루역 1번(송리단길)', '방이역 1번', '방이역 4번', '벌말어린이공원',
#        '오동나무공원(송파레미니스1단지)', 'Sh수협은행 오금동금융센터(아랫말어린이공원)', '석촌고분역',
#        '송파나루역 2번', '거여초등학교', '한성백제역 3번', '거여역 1번(거여공원)', '석촌고분역 4번',
#        '거여역', '방이동먹자골목', '석촌고분역 1번', '마천공원', '몽촌토성역', '아래방죽마을공원(율현초등학교)',
#        '잠실 관광특구', '한국교통안전공단 강남자동차검사소', '윗방죽마을공원', '개미어린이공원', '잠실역',
#        '삼전역 3번', '남천초등학교', '마천시장', '마천중앙시장', '대청초등학교', '마천역(마천초등학교)',
#        '삼전역 1번', '잠실나루역', '삼전역 4번', '새마을시장', '마천1치안센터',
# ...

# %%
sample = ",".join(df_sorted['상권_코드_명'].unique())  # 상권 코드 명 리스트를 쉼표로 구분된 문자열로 변환
params = {
    "상권_코드_명": sample,
    "기준_년분기_코드": 20221
}

# %%
base_url = "http://0.0.0.0:5001/data"

# %%
response = requests.get(base_url, params=params)

# %%
all_data = []

# %%
for store_code in df_sorted['상권_코드_명'].unique():
        params = {
            "상권_코드_명": store_code,
            "기준_년분기_코드": 20221
        }
        try:
            response = requests.get(base_url, params=params)
            response.raise_for_status()
            data = response.json()
            all_data.extend(data)  # 각 요청의 결과를 모아 리스트에 추가
        except requests.RequestException as e:
            continue  # 오류 발생 시 해당 상권 코드명에 대한 요청을 건너뛰고 계속 진행

# %%
# 성별에 따른 매출 금액으로 정렬
gender_sales = f"여성_매출_금액"
highest_gender_sales = sorted(all_data, key=lambda x: x['매출액'][gender_sales], reverse=True)

# %%
highest_gender_sales[:10]
# Out:
# [{'상권_코드_명': '잠실역',
#   '서비스_업종_코드_명': '일반의류',
#   '기준_년분기_코드': 20221,
#   '자치구_코드_명': '송파구',
#   '행정동_코드_명': '잠실6동',
#   '경도': 127.10126801274058,
#   '위도': 37.51398412500385,
#   '매출액': {'여성_매출_금액': 48278060209,
#    '남성_매출_금액': 21675719674,
#    '연령대_10_매출_금액': 129312265,
#    '연령대_20_매출_금액': 13795503010,
#    '연령대_30_매출_금액': 28907896576,
#    '연령대_40_매출_금액': 13058076680,
#    '연령대_50_매출_금액': 10083627023,
#    '연령대_60_이상_매출_금액': 3979364328},
#   'id': 'f371'},
#  {'상권_코드_명': '잠실 관광특구',
#   '서비스_업종_코드_명': '일반의류',
#   '기준_년분기_코드': 20221,
#   '자치구_코드_명': '송파구',
#   '행정동_코드_명': '방이2동',
#   '경도': 127.1152409425314,
#   '위도': 37.51643105790915,
#   '매출액': {'여성_매출_금액': 48241670583,
#    '남성_매출_금액': 21774614048,
#    '연령대_10_매출_금액': 129386659,
#    '연령대_20_매출_금액': 13773171438,
#    '연령대_30_매출_금액': 29022917069,
#    '연령대_40_매출_금액': 12976858620,
#    '연령대_50_매출_금액': 10200236410,
#    '연령대_60_이상_매출_금액': 3913714434},
#   'id': '982d'},
#  {'상권_코드_명': '가락시장',
#   '서비스_업종_코드_명': '반찬가게',
# ...

# %%
sales_summary = {}

# %%
for item in all_data:
        service_type = item['서비스_업종_코드_명']
        if service_type in sales_summary:
            sales_summary[service_type] += item['매출액']['여성_매출_금액']
        else:
            sales_summary[service_type] = item['매출액']['여성_매출_금액']

# %%
sorted_sales_summary = dict(sorted(sales_summary.items(), key=lambda x: x[1], reverse=True))

# %%
# '서비스_업종_코드_명' 별로 '여성_매출_금액'을 합산
sales_summary = {}
for item in highest_gender_sales:
    service_type = item['서비스_업종_코드_명']
    if service_type in sales_summary:
        sales_summary[service_type] += item['매출액']['여성_매출_금액']
    else:
        sales_summary[service_type] = item['매출액']['여성_매출_금액']

# %%
len(sales_summary)
# Out:
# 61

# %%
sorted_sales_summary = sorted(sales_summary.items(), key=lambda x: x[1], reverse=True)

# %%
# sales_summary 딕셔너리의 키를 추출
original_keys = list(sales_summary.keys())

# sorted_sales_summary에서 키만 추출 (정렬 후)
sorted_keys = [key for key, _ in sorted_sales_summary]

# 두 키 리스트의 순서 비교
if original_keys == sorted_keys:
    print("키의 순서가 동일합니다.")
else:
    print("키의 순서가 다릅니다.")
# Out:
# 키의 순서가 다릅니다.
